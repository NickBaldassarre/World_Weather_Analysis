# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import sys
sys.path.append("../")
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | homer
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | moose factory
# Processing Record 8 of Set 1 | asau
# Processing Record 9 of Set 1 | mandurah
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | yeniseysk
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | orlik
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | vinh
# Processing Record 26 of Set 1 | baghdad
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | port hardy
# Processing Record 29 of Set 1 | bilma
# Processing Record 30 of Set 1 | pevek
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 1 | colares
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | nizhnevartovsk
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | maumere
# Processing Record 39 of Set 1 | porto recanati
# Processing Record 40 of Set 1 | rio cuarto
# Processing Record 41 of Set 1 | kruisfontein
# Processing Record 42 of Set 1 | manggar
# Processing Record 43 of Set 1 | punta de bombon
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | sao felix do xingu
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | korla
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | lasa
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | gantt
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | hervey bay
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | broome
# Processing Record 13 of Set 2 | siniscola
# Processing Record 14 of Set 2 | megion
# Processing Record 15 of Set 2 | paamiut
# Processing Record 16 of Set 2 | hofn
# Processing Record 17 of Set 2 | naze
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | kupang
# Processing Record 21 of Set 2 | toamasina
# Processing Record 22 of Set 2 | taoudenni
# Processing Record 23 of Set 2 | tuy hoa
# Processing Record 24 of Set 2 | esperance
# Processing Record 25 of Set 2 | hualmay
# Processing Record 26 of Set 2 | cacapava do sul
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | melo
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 2 | tura
# Processing Record 34 of Set 2 | te anau
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | portland
# Processing Record 38 of Set 2 | vanderhoof
# Processing Record 39 of Set 2 | zhangye
# Processing Record 40 of Set 2 | sangar
# Processing Record 41 of Set 2 | hovd
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 2 | maningrida
# Processing Record 45 of Set 2 | flinders
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | walvis bay
# Processing Record 48 of Set 2 | russell
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | ligayan
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | babu
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | maldonado
# Processing Record 9 of Set 3 | sheopur
# Processing Record 10 of Set 3 | sao filipe
# Processing Record 11 of Set 3 | camacha
# Processing Record 12 of Set 3 | narsaq
# Processing Record 13 of Set 3 | pangnirtung
# Processing Record 14 of Set 3 | bhadohi
# Processing Record 15 of Set 3 | inuvik
# Processing Record 16 of Set 3 | sept-iles
# Processing Record 17 of Set 3 | soe
# Processing Record 18 of Set 3 | taitung
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | chalala
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | mtama
# Processing Record 23 of Set 3 | tulum
# Processing Record 24 of Set 3 | tiznit
# Processing Record 25 of Set 3 | aasiaat
# Processing Record 26 of Set 3 | rio gallegos
# Processing Record 27 of Set 3 | evensk
# Processing Record 28 of Set 3 | laem sing
# Processing Record 29 of Set 3 | bursol
# City not found. Skipping...
# Processing Record 30 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 31 of Set 3 | coihueco
# Processing Record 32 of Set 3 | grimari
# City not found. Skipping...
# Processing Record 33 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 3 | mandera
# Processing Record 37 of Set 3 | qaqortoq
# Processing Record 38 of Set 3 | fomboni
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 3 | honiara
# Processing Record 46 of Set 3 | srednekolymsk
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | buraydah
# Processing Record 49 of Set 3 | utinga
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | madimba
# Processing Record 2 of Set 4 | cockburn town
# Processing Record 3 of Set 4 | taltal
# Processing Record 4 of Set 4 | oriximina
# Processing Record 5 of Set 4 | fallon
# Processing Record 6 of Set 4 | mount gambier
# Processing Record 7 of Set 4 | severo-kurilsk
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 4 | oka
# Processing Record 11 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 4 | puro
# Processing Record 13 of Set 4 | alta floresta
# Processing Record 14 of Set 4 | kutum
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | ratnagiri
# Processing Record 19 of Set 4 | tezu
# Processing Record 20 of Set 4 | nuuk
# Processing Record 21 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 4 | kenora
# Processing Record 23 of Set 4 | comodoro rivadavia
# Processing Record 24 of Set 4 | ipueiras
# Processing Record 25 of Set 4 | zhigansk
# Processing Record 26 of Set 4 | bella union
# Processing Record 27 of Set 4 | phitsanulok
# Processing Record 28 of Set 4 | indiana
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | ingham
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 34 of Set 4 | calvinia
# Processing Record 35 of Set 4 | matara
# Processing Record 36 of Set 4 | moerai
# Processing Record 37 of Set 4 | sumbe
# Processing Record 38 of Set 4 | ixtapa
# Processing Record 39 of Set 4 | fowa
# Processing Record 40 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | lanchyn
# Processing Record 43 of Set 4 | cabo san lucas
# Processing Record 44 of Set 4 | leshan
# Processing Record 45 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 4 | jumla
# Processing Record 47 of Set 4 | acarau
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | la plata
# Processing Record 50 of Set 4 | kapaa
# Processing Record 1 of Set 5 | bonavista
# Processing Record 2 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | bharatpur
# Processing Record 5 of Set 5 | karaman
# Processing Record 6 of Set 5 | kodino
# Processing Record 7 of Set 5 | noumea
# Processing Record 8 of Set 5 | saint-georges
# Processing Record 9 of Set 5 | clyde
# Processing Record 10 of Set 5 | zhangjiakou
# Processing Record 11 of Set 5 | deder
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | guerrero negro
# Processing Record 14 of Set 5 | kalmunai
# Processing Record 15 of Set 5 | senanga
# Processing Record 16 of Set 5 | bambous virieux
# Processing Record 17 of Set 5 | beringovskiy
# Processing Record 18 of Set 5 | sorland
# Processing Record 19 of Set 5 | cherskiy
# Processing Record 20 of Set 5 | atasu
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | mahebourg
# Processing Record 23 of Set 5 | krasnoselkup
# Processing Record 24 of Set 5 | mumbwa
# Processing Record 25 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 5 | bardsir
# Processing Record 27 of Set 5 | hambantota
# Processing Record 28 of Set 5 | payson
# Processing Record 29 of Set 5 | telimele
# Processing Record 30 of Set 5 | pangai
# Processing Record 31 of Set 5 | elko
# Processing Record 32 of Set 5 | ayan
# Processing Record 33 of Set 5 | mogadishu
# Processing Record 34 of Set 5 | flin flon
# Processing Record 35 of Set 5 | hami
# Processing Record 36 of Set 5 | moron
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | harrisonburg
# Processing Record 39 of Set 5 | baiao
# Processing Record 40 of Set 5 | varhaug
# Processing Record 41 of Set 5 | bonthe
# Processing Record 42 of Set 5 | khatanga
# Processing Record 43 of Set 5 | trairi
# Processing Record 44 of Set 5 | allapalli
# Processing Record 45 of Set 5 | clyde river
# Processing Record 46 of Set 5 | bathsheba
# Processing Record 47 of Set 5 | marsaxlokk
# Processing Record 48 of Set 5 | kanigoro
# Processing Record 49 of Set 5 | edson
# Processing Record 50 of Set 5 | klaksvik
# Processing Record 1 of Set 6 | avera
# Processing Record 2 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 6 | salalah
# Processing Record 4 of Set 6 | miragoane
# Processing Record 5 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 6 | prince rupert
# Processing Record 7 of Set 6 | koungou
# Processing Record 8 of Set 6 | aksha
# Processing Record 9 of Set 6 | ola
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | palmerston
# Processing Record 12 of Set 6 | show low
# Processing Record 13 of Set 6 | namatanai
# Processing Record 14 of Set 6 | kamennomostskiy
# Processing Record 15 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 6 | poitiers
# Processing Record 17 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 6 | saint-pierre
# Processing Record 19 of Set 6 | peniche
# Processing Record 20 of Set 6 | belaya gora
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | marsa matruh
# Processing Record 23 of Set 6 | kozyatyn
# Processing Record 24 of Set 6 | nanortalik
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | chapais
# Processing Record 27 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 6 | waipawa
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | beaupre
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | northampton
# Processing Record 33 of Set 6 | igarape-miri
# City not found. Skipping...
# Processing Record 34 of Set 6 | kayes
# Processing Record 35 of Set 6 | daru
# Processing Record 36 of Set 6 | maria chiquita
# Processing Record 37 of Set 6 | natal
# Processing Record 38 of Set 6 | burkburnett
# Processing Record 39 of Set 6 | kyabe
# Processing Record 40 of Set 6 | kalabo
# Processing Record 41 of Set 6 | chauk
# Processing Record 42 of Set 6 | airai
# Processing Record 43 of Set 6 | grants
# Processing Record 44 of Set 6 | jakarta
# Processing Record 45 of Set 6 | tual
# Processing Record 46 of Set 6 | aksu
# Processing Record 47 of Set 6 | rio grande
# Processing Record 48 of Set 6 | longyearbyen
# Processing Record 49 of Set 6 | llano de piedra
# Processing Record 50 of Set 6 | raudeberg
# Processing Record 1 of Set 7 | loei
# Processing Record 2 of Set 7 | kirkuk
# Processing Record 3 of Set 7 | touros
# Processing Record 4 of Set 7 | zabid
# Processing Record 5 of Set 7 | ardalstangen
# Processing Record 6 of Set 7 | champerico
# Processing Record 7 of Set 7 | stamsund
# City not found. Skipping...
# Processing Record 8 of Set 7 | callander
# Processing Record 9 of Set 7 | vorukh
# Processing Record 10 of Set 7 | jidong
# Processing Record 11 of Set 7 | cayenne
# Processing Record 12 of Set 7 | cabedelo
# Processing Record 13 of Set 7 | fort dodge
# Processing Record 14 of Set 7 | campo verde
# Processing Record 15 of Set 7 | volchanets
# Processing Record 16 of Set 7 | havoysund
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 7 | geraldton
# Processing Record 20 of Set 7 | ahipara
# Processing Record 21 of Set 7 | pavlodar
# Processing Record 22 of Set 7 | nizhniy kuranakh
# Processing Record 23 of Set 7 | asyut
# Processing Record 24 of Set 7 | verkhniy baskunchak
# Processing Record 25 of Set 7 | vestmannaeyjar
# Processing Record 26 of Set 7 | bac lieu
# Processing Record 27 of Set 7 | talas
# Processing Record 28 of Set 7 | tecpan
# Processing Record 29 of Set 7 | maryville
# Processing Record 30 of Set 7 | luena
# Processing Record 31 of Set 7 | port-gentil
# Processing Record 32 of Set 7 | haapu
# City not found. Skipping...
# Processing Record 33 of Set 7 | mount isa
# Processing Record 34 of Set 7 | buala
# Processing Record 35 of Set 7 | inhambane
# Processing Record 36 of Set 7 | anapoima
# Processing Record 37 of Set 7 | ust-ilimsk
# Processing Record 38 of Set 7 | ihosy
# Processing Record 39 of Set 7 | leku
# Processing Record 40 of Set 7 | sinaloa
# Processing Record 41 of Set 7 | marawi
# Processing Record 42 of Set 7 | mildura
# Processing Record 43 of Set 7 | bara
# Processing Record 44 of Set 7 | venice
# Processing Record 45 of Set 7 | daoukro
# Processing Record 46 of Set 7 | honningsvag
# Processing Record 47 of Set 7 | astana
# Processing Record 48 of Set 7 | shache
# Processing Record 49 of Set 7 | alyangula
# Processing Record 50 of Set 7 | kurchum
# Processing Record 1 of Set 8 | knysna
# Processing Record 2 of Set 8 | panama city
# Processing Record 3 of Set 8 | katsuura
# Processing Record 4 of Set 8 | miri
# Processing Record 5 of Set 8 | magadan
# Processing Record 6 of Set 8 | palmas
# Processing Record 7 of Set 8 | atambua
# Processing Record 8 of Set 8 | teeli
# Processing Record 9 of Set 8 | maniitsoq
# Processing Record 10 of Set 8 | mackay
# Processing Record 11 of Set 8 | lorengau
# Processing Record 12 of Set 8 | saint anthony
# Processing Record 13 of Set 8 | la reforma
# Processing Record 14 of Set 8 | sungaipenuh
# Processing Record 15 of Set 8 | uyuni
# Processing Record 16 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 17 of Set 8 | inverell
# Processing Record 18 of Set 8 | rincon
# Processing Record 19 of Set 8 | port lincoln
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | merauke
# Processing Record 22 of Set 8 | santa isabel
# Processing Record 23 of Set 8 | ambajogai
# Processing Record 24 of Set 8 | tupik
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | isla vista
# Processing Record 27 of Set 8 | nikolskoye
# Processing Record 28 of Set 8 | lagoa
# Processing Record 29 of Set 8 | salinas
# Processing Record 30 of Set 8 | oranjemund
# Processing Record 31 of Set 8 | tabuk
# Processing Record 32 of Set 8 | zyryanka
# Processing Record 33 of Set 8 | kloulklubed
# Processing Record 34 of Set 8 | polunochnoye
# Processing Record 35 of Set 8 | ust-omchug
# Processing Record 36 of Set 8 | amboise
# Processing Record 37 of Set 8 | luderitz
# Processing Record 38 of Set 8 | anju
# Processing Record 39 of Set 8 | byron bay
# Processing Record 40 of Set 8 | humboldt
# Processing Record 41 of Set 8 | kilindoni
# Processing Record 42 of Set 8 | nome
# Processing Record 43 of Set 8 | bontang
# Processing Record 44 of Set 8 | ngaoundere
# Processing Record 45 of Set 8 | constitucion
# Processing Record 46 of Set 8 | dikson
# Processing Record 47 of Set 8 | loa janan
# Processing Record 48 of Set 8 | rojhan
# Processing Record 49 of Set 8 | beyneu
# Processing Record 50 of Set 8 | pekan
# Processing Record 1 of Set 9 | chokurdakh
# Processing Record 2 of Set 9 | gazli
# Processing Record 3 of Set 9 | gusinoye ozero
# Processing Record 4 of Set 9 | perevolotskiy
# Processing Record 5 of Set 9 | san onofre
# Processing Record 6 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 9 | dombarovskiy
# Processing Record 8 of Set 9 | dalbandin
# Processing Record 9 of Set 9 | erzin
# Processing Record 10 of Set 9 | ileza
# Processing Record 11 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 12 of Set 9 | port blair
# Processing Record 13 of Set 9 | sur
# Processing Record 14 of Set 9 | svetlogorsk
# Processing Record 15 of Set 9 | matsanga
# City not found. Skipping...
# Processing Record 16 of Set 9 | saint-michel-des-saints
# Processing Record 17 of Set 9 | lugoba
# Processing Record 18 of Set 9 | prieska
# Processing Record 19 of Set 9 | wanning
# Processing Record 20 of Set 9 | codrington
# Processing Record 21 of Set 9 | puerto escondido
# Processing Record 22 of Set 9 | cap malheureux
# Processing Record 23 of Set 9 | bileca
# Processing Record 24 of Set 9 | vao
# Processing Record 25 of Set 9 | palu
# Processing Record 26 of Set 9 | imbituba
# Processing Record 27 of Set 9 | seminole
# Processing Record 28 of Set 9 | swan hill
# Processing Record 29 of Set 9 | henties bay
# Processing Record 30 of Set 9 | uni
# Processing Record 31 of Set 9 | kurri kurri
# Processing Record 32 of Set 9 | kuanhsi
# City not found. Skipping...
# Processing Record 33 of Set 9 | dauphin
# Processing Record 34 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 9 | bubaque
# Processing Record 36 of Set 9 | senneterre
# Processing Record 37 of Set 9 | deer lake
# Processing Record 38 of Set 9 | chernyshevskiy
# Processing Record 39 of Set 9 | inirida
# Processing Record 40 of Set 9 | kabinda
# Processing Record 41 of Set 9 | howard springs
# Processing Record 42 of Set 9 | pustoshka
# Processing Record 43 of Set 9 | hochdorf
# Processing Record 44 of Set 9 | crailsheim
# Processing Record 45 of Set 9 | adre
# Processing Record 46 of Set 9 | komsomolskiy
# Processing Record 47 of Set 9 | barcelos
# Processing Record 48 of Set 9 | floro
# Processing Record 49 of Set 9 | lianzhou
# Processing Record 50 of Set 9 | vardo
# Processing Record 1 of Set 10 | saurimo
# Processing Record 2 of Set 10 | emerald
# Processing Record 3 of Set 10 | aswan
# Processing Record 4 of Set 10 | ostrovnoy
# Processing Record 5 of Set 10 | mkushi
# Processing Record 6 of Set 10 | bud
# Processing Record 7 of Set 10 | nantucket
# Processing Record 8 of Set 10 | kismayo
# Processing Record 9 of Set 10 | araouane
# Processing Record 10 of Set 10 | benjamin constant
# Processing Record 11 of Set 10 | karratha
# Processing Record 12 of Set 10 | isiro
# Processing Record 13 of Set 10 | izmit
# Processing Record 14 of Set 10 | mikhaylovka
# Processing Record 15 of Set 10 | sarahan
# Processing Record 16 of Set 10 | jinka
# Processing Record 17 of Set 10 | noormarkku
# Processing Record 18 of Set 10 | muyezerskiy
# Processing Record 19 of Set 10 | kudahuvadhoo
# Processing Record 20 of Set 10 | puerto del rosario
# Processing Record 21 of Set 10 | paracuru
# Processing Record 22 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 10 | russkaya polyana
# Processing Record 24 of Set 10 | taksimo
# Processing Record 25 of Set 10 | derzhavinsk
# Processing Record 26 of Set 10 | ca mau
# Processing Record 27 of Set 10 | udachnyy
# Processing Record 28 of Set 10 | banavar
# Processing Record 29 of Set 10 | mana
# Processing Record 30 of Set 10 | muros
# Processing Record 31 of Set 10 | eydhafushi
# Processing Record 32 of Set 10 | soure
# Processing Record 33 of Set 10 | kinsale
# Processing Record 34 of Set 10 | harper
# Processing Record 35 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 10 | san patricio
# Processing Record 37 of Set 10 | carutapera
# Processing Record 38 of Set 10 | mahajanga
# Processing Record 39 of Set 10 | esil
# Processing Record 40 of Set 10 | narasapur
# Processing Record 41 of Set 10 | santa isabel do rio negro
# Processing Record 42 of Set 10 | vila franca do campo
# Processing Record 43 of Set 10 | kamenka
# Processing Record 44 of Set 10 | katherine
# Processing Record 45 of Set 10 | randvere
# City not found. Skipping...
# Processing Record 46 of Set 10 | meiringen
# Processing Record 47 of Set 10 | san rafael
# Processing Record 48 of Set 10 | nizamabad
# Processing Record 49 of Set 10 | burica
# City not found. Skipping...
# Processing Record 50 of Set 10 | tacuarembo
# Processing Record 1 of Set 11 | marrakesh
# Processing Record 2 of Set 11 | dalvik
# Processing Record 3 of Set 11 | vicksburg
# Processing Record 4 of Set 11 | adrar
# Processing Record 5 of Set 11 | fort wellington
# Processing Record 6 of Set 11 | talnakh
# Processing Record 7 of Set 11 | gizo
# Processing Record 8 of Set 11 | itacoatiara
# Processing Record 9 of Set 11 | hangu
# Processing Record 10 of Set 11 | perth
# Processing Record 11 of Set 11 | sokna
# Processing Record 12 of Set 11 | acajutla
# Processing Record 13 of Set 11 | fengrun
# Processing Record 14 of Set 11 | sidvokodvo
# Processing Record 15 of Set 11 | portel
# Processing Record 16 of Set 11 | healdsburg
# Processing Record 17 of Set 11 | voh
# Processing Record 18 of Set 11 | andenes
# Processing Record 19 of Set 11 | istok
# Processing Record 20 of Set 11 | saint-augustin
# Processing Record 21 of Set 11 | segezha
# Processing Record 22 of Set 11 | mazamari
# Processing Record 23 of Set 11 | kungurtug
# Processing Record 24 of Set 11 | sorong
# Processing Record 25 of Set 11 | fortuna
# Processing Record 26 of Set 11 | adamovka
# Processing Record 27 of Set 11 | stavyshche
# Processing Record 28 of Set 11 | huambo
# Processing Record 29 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 11 | bambanglipuro
# Processing Record 31 of Set 11 | kaeo
# Processing Record 32 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 11 | alberton
# Processing Record 34 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 11 | piacabucu
# Processing Record 36 of Set 11 | bayir
# Processing Record 37 of Set 11 | balaipungut
# Processing Record 38 of Set 11 | pacific grove
# Processing Record 39 of Set 11 | santa maria
# Processing Record 40 of Set 11 | kharp
# Processing Record 41 of Set 11 | murupara
# Processing Record 42 of Set 11 | madang
# Processing Record 43 of Set 11 | suntar
# Processing Record 44 of Set 11 | zuwarah
# Processing Record 45 of Set 11 | deputatskiy
# Processing Record 46 of Set 11 | aguimes
# Processing Record 47 of Set 11 | shingu
# Processing Record 48 of Set 11 | skiros
# City not found. Skipping...
# Processing Record 49 of Set 11 | lamu
# Processing Record 50 of Set 11 | cururupu
# Processing Record 1 of Set 12 | vostok
# Processing Record 2 of Set 12 | artigas
# Processing Record 3 of Set 12 | padang
# Processing Record 4 of Set 12 | jaguariaiva
# Processing Record 5 of Set 12 | freeport
# Processing Record 6 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 12 | bundaberg
# Processing Record 8 of Set 12 | san vicente
# Processing Record 9 of Set 12 | grand gaube
# Processing Record 10 of Set 12 | road town
# Processing Record 11 of Set 12 | margate
# Processing Record 12 of Set 12 | sungairaya
# Processing Record 13 of Set 12 | puerto el triunfo
# Processing Record 14 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 15 of Set 12 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 16 of Set 12 | les cayes
# Processing Record 17 of Set 12 | kokstad
# Processing Record 18 of Set 12 | husavik
# Processing Record 19 of Set 12 | calbuco
# Processing Record 20 of Set 12 | smolenka
# Processing Record 21 of Set 12 | porto torres
# Processing Record 22 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | tanda
# Processing Record 24 of Set 12 | ranau
# Processing Record 25 of Set 12 | bethanien
# Processing Record 26 of Set 12 | yermakovskoye
# Processing Record 27 of Set 12 | betsiamites
# Processing Record 28 of Set 12 | uruzgan
# Processing Record 29 of Set 12 | kenai
# Processing Record 30 of Set 12 | okhotsk
# Processing Record 31 of Set 12 | nanpara
# Processing Record 32 of Set 12 | killybegs
# Processing Record 33 of Set 12 | maceio
# Processing Record 34 of Set 12 | ostersund
# Processing Record 35 of Set 12 | jawhar
# Processing Record 36 of Set 12 | pemba
# Processing Record 37 of Set 12 | najran
# Processing Record 38 of Set 12 | port macquarie
# Processing Record 39 of Set 12 | kambove
# Processing Record 40 of Set 12 | valparaiso
# Processing Record 41 of Set 12 | kavaratti
# Processing Record 42 of Set 12 | bilibino
# Processing Record 43 of Set 12 | uvinza
# Processing Record 44 of Set 12 | huilong
# Processing Record 45 of Set 12 | college
# Processing Record 46 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 12 | porto novo
# Processing Record 48 of Set 12 | dunmore town
# Processing Record 49 of Set 12 | jiblah
# Processing Record 50 of Set 12 | souillac
# Processing Record 1 of Set 13 | port moresby
# Processing Record 2 of Set 13 | karabuk
# Processing Record 3 of Set 13 | gat
# Processing Record 4 of Set 13 | san jeronimo
# Processing Record 5 of Set 13 | anadyr
# Processing Record 6 of Set 13 | brunswick
# Processing Record 7 of Set 13 | groningen
# Processing Record 8 of Set 13 | bahia blanca
# Processing Record 9 of Set 13 | mangrol
# Processing Record 10 of Set 13 | pechora
# Processing Record 11 of Set 13 | nouadhibou
# Processing Record 12 of Set 13 | odweyne
# Processing Record 13 of Set 13 | makinsk
# Processing Record 14 of Set 13 | amapa
# Processing Record 15 of Set 13 | vagamo
# Processing Record 16 of Set 13 | kollo
# Processing Record 17 of Set 13 | durazno
# Processing Record 18 of Set 13 | linxia
# Processing Record 19 of Set 13 | svobodnyy
# Processing Record 20 of Set 13 | ialibu
# Processing Record 21 of Set 13 | beloha
# Processing Record 22 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | leh
# Processing Record 24 of Set 13 | lunsar
# Processing Record 25 of Set 13 | antofagasta
# Processing Record 26 of Set 13 | sambava
# Processing Record 27 of Set 13 | smalininkai
# Processing Record 28 of Set 13 | sibu
# Processing Record 29 of Set 13 | leningradskiy
# Processing Record 30 of Set 13 | zolnoye
# City not found. Skipping...
# Processing Record 31 of Set 13 | nemuro
# Processing Record 32 of Set 13 | akhaldaba
# Processing Record 33 of Set 13 | lata
# Processing Record 34 of Set 13 | brainerd
# Processing Record 35 of Set 13 | burnie
# Processing Record 36 of Set 13 | springbok
# Processing Record 37 of Set 13 | claveria
# Processing Record 38 of Set 13 | aksarka
# Processing Record 39 of Set 13 | dongsheng
# Processing Record 40 of Set 13 | mugur-aksy
# Processing Record 41 of Set 13 | dzilam gonzalez
# Processing Record 42 of Set 13 | batagay-alyta
# Processing Record 43 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 13 | asamankese
# Processing Record 45 of Set 13 | toulepleu
# City not found. Skipping...
# Processing Record 46 of Set 13 | ilhabela
# Processing Record 47 of Set 13 | karlstad
# Processing Record 48 of Set 13 | namangan
# Processing Record 49 of Set 13 | kovdor
# Processing Record 50 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 14 | magdalena
# Processing Record 2 of Set 14 | sarkand
# Processing Record 3 of Set 14 | hobyo
# Processing Record 4 of Set 14 | viransehir
# Processing Record 5 of Set 14 | kothi
# Processing Record 6 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 7 of Set 14 | ekhabi
# Processing Record 8 of Set 14 | morden
# Processing Record 9 of Set 14 | landskrona
# Processing Record 10 of Set 14 | sao raimundo das mangabeiras
# Processing Record 11 of Set 14 | samarai
# Processing Record 12 of Set 14 | corrales
# Processing Record 13 of Set 14 | chateaubelair
# Processing Record 14 of Set 14 | moctezuma
# Processing Record 15 of Set 14 | golspie
# Processing Record 16 of Set 14 | bitlis
# Processing Record 17 of Set 14 | caravelas
# Processing Record 18 of Set 14 | pemangkat
# Processing Record 19 of Set 14 | yueyang
# Processing Record 20 of Set 14 | nabire
# Processing Record 21 of Set 14 | isangel
# Processing Record 22 of Set 14 | eston
# Processing Record 23 of Set 14 | vila velha
# Processing Record 24 of Set 14 | zabol
# Processing Record 25 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 26 of Set 14 | trapani
# Processing Record 27 of Set 14 | tete
# Processing Record 28 of Set 14 | kompaniyivka
# Processing Record 29 of Set 14 | parana
# Processing Record 30 of Set 14 | coihaique
# Processing Record 31 of Set 14 | olafsvik
# Processing Record 32 of Set 14 | ayolas
# Processing Record 33 of Set 14 | agadez
# Processing Record 34 of Set 14 | srikakulam
# Processing Record 35 of Set 14 | pucallpa
# Processing Record 36 of Set 14 | lewistown
# Processing Record 37 of Set 14 | balkhash
# Processing Record 38 of Set 14 | qianan
# Processing Record 39 of Set 14 | ninghai
# Processing Record 40 of Set 14 | bitung
# Processing Record 41 of Set 14 | cabo rojo
# Processing Record 42 of Set 14 | nicoya
# Processing Record 43 of Set 14 | nkayi
# Processing Record 44 of Set 14 | khorinsk
# Processing Record 45 of Set 14 | lomza
# Processing Record 46 of Set 14 | kralendijk
# Processing Record 47 of Set 14 | zyryanovsk
# Processing Record 48 of Set 14 | sonoita
# Processing Record 49 of Set 14 | tombouctou
# Processing Record 50 of Set 14 | kochi
# Processing Record 1 of Set 15 | gogrial
# Processing Record 2 of Set 15 | hetauda
# Processing Record 3 of Set 15 | tongliao
# Processing Record 4 of Set 15 | santa ana
# Processing Record 5 of Set 15 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 6 of Set 15 | katete
# Processing Record 7 of Set 15 | pangody
# Processing Record 8 of Set 15 | ugoofaaru
# Processing Record 9 of Set 15 | arman
# Processing Record 10 of Set 15 | charters towers
# Processing Record 11 of Set 15 | sai buri
# Processing Record 12 of Set 15 | saint cloud
# Processing Record 13 of Set 15 | thyboron
# Processing Record 14 of Set 15 | khorixas
# Processing Record 15 of Set 15 | launceston
# Processing Record 16 of Set 15 | ishigaki
# Processing Record 17 of Set 15 | tambacounda
# Processing Record 18 of Set 15 | pilar
# Processing Record 19 of Set 15 | dwarka
# Processing Record 20 of Set 15 | anloga
# Processing Record 21 of Set 15 | spornoye
# Processing Record 22 of Set 15 | caborca
# Processing Record 23 of Set 15 | sakakah
# Processing Record 24 of Set 15 | illela
# Processing Record 25 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 15 | kurtamysh
# Processing Record 27 of Set 15 | iberia
# Processing Record 28 of Set 15 | roald
# Processing Record 29 of Set 15 | pyay
# Processing Record 30 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 31 of Set 15 | lasem
# Processing Record 32 of Set 15 | hawalli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cape Town      ZA -33.9258   18.4232     60.91        82           0
# 1     Butaritari      KI   3.0707  172.7902     81.86        72          18
# 2        Mataura      NZ -46.1927  168.8643     61.48        66          53
# 3          Homer      US  59.6425 -151.5483     40.89        70         100
# 4      Busselton      AU -33.6500  115.3333     66.34        58          96
# 5        Rikitea      PF -23.1203 -134.9692     78.40        63           7
# 6  Moose Factory      CA  51.2585  -80.6094     13.98        92           0
# 7           Asau      RO  46.4333   26.4000     37.96        78          45
# 8       Mandurah      AU -32.5500  115.7000     70.92        53           1
# 9           Chuy      UY -33.6971  -53.4616     60.87        86         100
#
#    Wind Speed Current Description
# 0       11.99           clear sky
# 1       12.17          few clouds
# 2        2.66       broken clouds
# 3        3.44          light rain
# 4        5.84     overcast clouds
# 5        8.75           clear sky
# 6        3.44           clear sky
# 7        6.76    scattered clouds
# 8       10.20           clear sky
# 9        5.88     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
